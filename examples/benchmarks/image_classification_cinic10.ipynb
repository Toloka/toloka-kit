# %% [markdown]
# # Image classification on CINIC-10

# %% [markdown]
# Dataset source: [https://github.com/BayesWatch/cinic-10](https://github.com/BayesWatch/cinic-10)
#
# License: [MIT](https://github.com/BayesWatch/cinic-10/blob/master/LICENSE)

# %% [markdown]
# To get acquainted with Toloka tools for free, you can use the promo code **TOLOKAKIT1** on $20 on your [profile page](https://toloka.yandex.com/requester/profile?utm_source=github&utm_medium=site&utm_campaign=tolokakit) after registration.

# %% [markdown]
# ### Call to action
# If you found some bugs or have a new feature idea, don't hesitate to [open a new issue on Github](https://github.com/Toloka/toloka-kit/issues/new/choose).
# Like our library and examples? Star [our repo on Github](https://github.com/Toloka/toloka-kit)

# %% [markdown]
# ## Install dependencies and import

# %%
# %%capture
# !pip install toloka-kit==0.1.26
# !pip install crowd-kit==1.0.0
# !pip install ipyplot # display images
# Out:
# Requirement already satisfied: ipyplot in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipyplot) (1.20.0)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipyplot) (8.3.2)
# Requirement already satisfied: shortuuid in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipyplot) (1.0.1)
# Requirement already satisfied: IPython in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipyplot) (7.26.0)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (4.3.3)
# Requirement already satisfied: pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (56.0.0)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (0.1.2)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (0.1.2)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (3.0.20)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from IPython->ipyplot) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->IPython->ipyplot) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pexpect>4.3->IPython->ipyplot) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->ipyplot) (0.2.5)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from traitlets>=4.2->IPython->ipyplot) (1.16.0)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from traitlets>=4.2->IPython->ipyplot) (0.2.0)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: crowd-kit==0.0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: attrs in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from crowd-kit==0.0.5) (21.2.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from crowd-kit==0.0.5) (0.24.2)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from crowd-kit==0.0.5) (1.3.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from crowd-kit==0.0.5) (4.62.2)
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from crowd-kit==0.0.5) (3.6.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from crowd-kit==0.0.5) (1.20.0)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk->crowd-kit==0.0.5) (8.0.1)
# Requirement already satisfied: regex in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk->crowd-kit==0.0.5) (2021.9.24)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk->crowd-kit==0.0.5) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->crowd-kit==0.0.5) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->crowd-kit==0.0.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->crowd-kit==0.0.5) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->crowd-kit==0.0.5) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->crowd-kit==0.0.5) (1.7.1)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: toloka-kit==0.1.13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.1.13)
# Requirement already satisfied: cattrs>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (1.8.0)
# Requirement already satisfied: simplejson in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (3.17.5)
# Requirement already satisfied: attrs>=21.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (21.2.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (1.3.2)
# Requirement already satisfied: docstring-parser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (0.10)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (2.26.0)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from toloka-kit==0.1.13) (1.26.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->toloka-kit==0.1.13) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->toloka-kit==0.1.13) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->toloka-kit==0.1.13) (1.20.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->toloka-kit==0.1.13) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->toloka-kit==0.1.13) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->toloka-kit==0.1.13) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->toloka-kit==0.1.13) (3.2)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import datetime
import time
import pandas as pd
import numpy as np
import ipyplot
from sklearn.metrics import balanced_accuracy_score
import os
import logging
import sys
import getpass

import toloka.client as toloka
import toloka.client.project.template_builder as tb

from crowdkit.aggregation import DawidSkene
# %matplotlib inline

# %%
logging.basicConfig(
    format='[%(levelname)s] %(name)s: %(message)s',
    level=logging.INFO,
    stream=sys.stdout,
)

# %% [markdown]
# # Load the dataset

# %%
N_ROWS = 1000

# %%
def sample_stratified(df, label_column, n_rows):
    """Function to sample n_rows from a dataframe while presenving class distribution"""
    return df.groupby(label_column, group_keys=False) \
            .apply(lambda x: x.sample(int(np.rint(n_rows*len(x)/len(df))))) \
            .sample(frac=1).reset_index(drop=True)

base_url = 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10'
df = pd.read_csv(os.path.join(base_url, 'test.csv'))
df['img_url'] = df.img_path.apply(lambda p: os.path.join(base_url, p))

df = sample_stratified(df, 'label', n_rows=N_ROWS)
df.head()
# Out:
#                            img_path label  \
# 0     test/ship/n03545470_11883.png  ship
# 1       test/dog/n02111889_9460.png   dog
# 2      test/frog/n01645776_9028.png  frog
# 3     test/frog/n01639765_21028.png  frog
# 4  test/dog/cifar10-train-45915.png   dog
#
#                                              img_url
# 0  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...
# 1  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...
# 2  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...
# 3  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...
# 4  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...

# %%
ipyplot.plot_class_representations(images=df.img_url, labels=df.label, img_width=70)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-bNAwUYjAubpsHSPtZujZM3 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-bNAwUYjAubpsHSPtZujZM3 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-bNAwUYjAubpsHSPtZujZM3 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-bNAwUYjAubpsHSPtZujZM3:checked ~ #ipyplot-html-viewer-textarea-bNAwUYjAubpsHSPtZujZM3 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-bNAwUYjAubpsHSPtZujZM3:checked + #ipyplot-html-viewer-label-bNAwUYjAubpsHSPtZujZM3:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-bNAwUYjAubpsHSPtZujZM3">
#         <label id="ipyplot-html-viewer-label-bNAwUYjAubpsHSPtZujZM3" for="ipyplot-html-viewer-toggle-bNAwUYjAubpsHSPtZujZM3">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-bNAwUYjAubpsHSPtZujZM3" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-VwZcQgh7ztQMjU3PuoeW5a {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a {
#             width: 70px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a {
#             width: 70px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a img {
#             width: 70px;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VwZcQgh7ztQMjU3PuoeW5a">
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NqHM9A2zRP4oVA6vsnxyCr" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/cifar10-train-41696.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/cifar10-train-41696.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NqHM9A2zRP4oVA6vsnxyCr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NKVdpDYUXBi56CnV3Xoku5" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03498781_5177.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03498781_5177.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NKVdpDYUXBi56CnV3Xoku5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-GQ9y9A67TYPiMBBYPCHAAG" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n02011943_4339.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n02011943_4339.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-GQ9y9A67TYPiMBBYPCHAAG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-H7EycZkWHhG6UFyjaAxASr" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02124075_2053.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02124075_2053.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-H7EycZkWHhG6UFyjaAxASr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-6EuTDty54DP28wYDbmPV2a" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/cifar10-test-4383.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/cifar10-test-4383.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-6EuTDty54DP28wYDbmPV2a">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-pl
#         <style>
#         #ipyplot-imgs-container-div-VwZcQgh7ztQMjU3PuoeW5a {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a {
#             width: 70px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a {
#             width: 70px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a img {
#             width: 70px;
#         }
#
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VwZcQgh7ztQMjU3PuoeW5a">
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NqHM9A2zRP4oVA6vsnxyCr" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/cifar10-train-41696.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/cifar10-train-41696.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NqHM9A2zRP4oVA6vsnxyCr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NKVdpDYUXBi56CnV3Xoku5" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03498781_5177.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03498781_5177.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-NKVdpDYUXBi56CnV3Xoku5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-GQ9y9A67TYPiMBBYPCHAAG" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n02011943_4339.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n02011943_4339.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-GQ9y9A67TYPiMBBYPCHAAG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-H7EycZkWHhG6UFyjaAxASr" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02124075_2053.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02124075_2053.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-H7EycZkWHhG6UFyjaAxASr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-6EuTDty54DP28wYDbmPV2a" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/cifar10-test-4383.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/cifar10-test-4383.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-6EuTDty54DP28wYDbmPV2a">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-bS9ytusaWo9XgL4Ak2D6g8" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02111889_9460.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02111889_9460.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-bS9ytusaWo9XgL4Ak2D6g8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VwZcQgh7ztQMjU3PuoeW5a">
#         <div id="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-Sctxg3Si96PewDkhpD4MMc" class="ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a">
#             <h4 style="font-size: 12px; word-wrap: break-word;">frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01645776_9028.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01645776_9028.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VwZcQgh7ztQMjU3PuoeW5a-Sc

# %% [markdown]
# # Setup the project

# %%
toloka_client = toloka.TolokaClient(getpass.getpass('Enter your OAuth token: '), 'PRODUCTION') # Or switch to 'SANDBOX'

# %% [markdown]
# ## Create project

# %%
project = toloka.Project(
    public_name='Small images classification',
    public_description='Classify small images into 10 categories',
    private_comment='OOTB: CINIC-10'
)

# %%
input_specification = {'image': toloka.project.UrlSpec()}
output_specification = {'result': toloka.project.StringSpec()}

# %%
CINIC_LABELS = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
len(CINIC_LABELS)
# Out:
# 10

# %% [markdown]
# ## Annotator interface

# %%
image_viewer = tb.ImageViewV1(tb.InputData('image'), 
                              ratio=[1, 1],
                              popup=False,
                             )

label_buttons = [tb.GroupFieldOption(l, l.capitalize()) for l in CINIC_LABELS]
radio_group_field = tb.ButtonRadioGroupFieldV1(
    tb.OutputData('result'),
    label_buttons,
    validation=tb.RequiredConditionV1(),
)

task_width_plugin = tb.TolokaPluginV1(
    'scroll',
    task_width=300,
)

hot_keys_plugin = tb.HotkeysPluginV1(
    key_1=tb.SetActionV1(tb.OutputData('result'), 'airplane'),
    key_2=tb.SetActionV1(tb.OutputData('result'), 'automobile'),
    key_3=tb.SetActionV1(tb.OutputData('result'), 'bird'),
    key_4=tb.SetActionV1(tb.OutputData('result'), 'cat'),
    key_5=tb.SetActionV1(tb.OutputData('result'), 'deer'),
    key_6=tb.SetActionV1(tb.OutputData('result'), 'dog'),
    key_7=tb.SetActionV1(tb.OutputData('result'), 'frog'),
    key_8=tb.SetActionV1(tb.OutputData('result'), 'horse'),
    key_9=tb.SetActionV1(tb.OutputData('result'), 'ship'),
    key_0=tb.SetActionV1(tb.OutputData('result'), 'truck'),
)

project_interface = toloka.project.TemplateBuilderViewSpec(
    config=tb.TemplateBuilder(
        view=tb.ListViewV1([image_viewer, radio_group_field]),
        plugins=[task_width_plugin, hot_keys_plugin],
    )
)

project.task_spec = toloka.project.task_spec.TaskSpec(
    input_spec=input_specification,
    output_spec=output_specification,
    view_spec=project_interface,
)

# %%
project.public_instructions = """
In this task, you will see images from 10 different classes.<br/>
Your task is to classify these images.<br/>

<b>Some images are blurry and hard to label</b>. That's the nature of the task, so just assign whatever label seems most appropriate.

How to complete the task:
<ul>
<li>Look at the picture.</li>
<li>Click on the image to resize it. You can rotate the image if it's in the wrong orientation.</li>
<li>Chose one of the possible answers. If the picture is unavailable or you have any other technical difficulty, please write us about it.</li>
<li>If you think that you can not classify the image correctly, choose the most appropriate label in your opinion.</li>
<li>You can use keyboard shortcuts (numbers from 1 to 0) to pick labels.</li>
</ul>
""".strip()

# %%
project = toloka_client.create_project(project)
# Out:
# [INFO] toloka.client: A new project with ID "60772" has been created. Link to open in web interface: https://toloka.yandex.com/requester/project/60772

# %% [markdown]
# ## Create training tasks

# %%
training_pool = toloka.training.Training(project_id=project.id,
    private_name='Training pool',  
    training_tasks_in_task_suite_count=10, 
    task_suites_required_to_pass=1, 
    may_contain_adult_content=False,
    inherited_instructions=True,
    assignment_max_duration_seconds=60*5,
    retry_training_after_days=1,
    mix_tasks_in_creation_order=True,
    shuffle_tasks_in_task_suite=True,
)

# %%
training_pool = toloka_client.create_training(training_pool)
# Out:
# [INFO] toloka.client: A new training with ID "28225833" has been created. Link to open in web interface: https://toloka.yandex.com/requester/project/60772/training/28225833

# %%
label_examples = {label: df[df.label == label].head(1).img_url.item() for label in CINIC_LABELS}
tasks = [
    toloka.Task(input_values={'image': url}, 
    known_solutions=[toloka.task.BaseTask.KnownSolution(output_values={'result': label})],   
    message_on_unknown_solution=f'Incorrect label! The actual label is: {label}',
    infinite_overlap=True,
    pool_id=training_pool.id)
    for label, url in label_examples.items()
]
toloka_client.create_tasks(tasks, allow_defaults=True)
# Out:
# TaskBatchCreateResult(_unexpected={}, items={'0': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/cifar10-train-41696.png'}, known_solutions=[BaseTask.KnownSolution(_unexpected={}, output_values={'result': 'airplane'}, correctness_weight=1.0)], message_on_unknown_solution='Incorrect label! The actual label is: airplane', id='0001aeb129--6152d4c9af6cdf0b9a4b5d44', infinite_overlap=True, overlap=None, pool_id='28225833', remaining_overlap=None, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 37, 590000), baseline_solutions=None), '1': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03498781_5177.png'}, known_solutions=[BaseTask.KnownSolution(_unexpected={}, output_values={'result': 'automobile'}, correctness_weight=1.0)], message_on_unknown_solution='Incorrect label! The actual label is: automobile', id='0001aeb129--6152d4c9af6cdf0b9a4b5d46', infinite_overlap=True, overlap=None, pool_id='28225833', remaining_overlap=None, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 37, 667000), baseline_solutions=None), '2': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n02011943_4339.png'}, known_solutions=[BaseTask.KnownSolution(_unexpected={}, output_values={'result': 'bird'}, correctness_weight=1.0)], message_on_unknown_solution='Incorrect label! The actual label is: bird', id='0001aeb129--6152d4c9af6cdf0b9a4b5d4b', infinite_overlap=True, overlap=None, pool_id='28225833', remaining_overlap=None, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 37, 754000), baseline_solutions=None), '3': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02124075_2053.png'}, known_solutions=[BaseTask.KnownSolution(_unexpected={}, output_values={'result': 'cat'}, correctness_weight=1.0)], message_on_unknown_solution='Incorrect label! The actual label is: cat', id='0001aeb129--6152d4c9af6cdf0b9a4b5d4f', infinite_overlap=True, overlap=None, pool_id='28225833', remaining_overlap=None, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 37, 832000), baseline_solutions=None), '4': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/cifar10-test-4383.png'}, known_solutions=[BaseTask.KnownSolution(_unexpected={}, output_values={'result': 'deer'}, correctness_weight=1.0)], message_on_unknown_solution='Incorrect label! The actual label is: deer', id='0001aeb129--6152d4c9af6cdf0b9a4b5d52', infinite_overlap=True, overlap=None, pool_id='28225833', remaining_overlap=None, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 37, 933000), baseline_solutions=None), '5': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02111889_9460.png'}, known_solutions=[BaseTask.KnownSolution(_unexpected={}, output_values={'result': 'dog'}, correctness_weight=1.0)], message_on_unknown_solution='Incorrect label! The actual label is: dog', id='0001aeb129--6152d4c9af6cdf0b9a4b5d54', infinite_overlap=True, overlap=None, pool_id='28225833', remaining_overlap=None, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 37, 993000), baseline_solutions=None), '6': Task(_unexpe ...

# %% [markdown]
# ## Create task Pool

# %%
pool = toloka.Pool(
    project_id=project.id,
    private_name='Pool',  
    may_contain_adult_content=False,
    reward_per_assignment=0.01,  
    assignment_max_duration_seconds=60*5,  
    will_expire=datetime.datetime.utcnow() + datetime.timedelta(days=365),
)
pool.defaults = toloka.pool.Pool.Defaults(
    default_overlap_for_new_tasks=5,
    default_overlap_for_new_task_suites=0,
)
pool.set_mixer_config(
    real_tasks_count=10,
)
pool.filter = toloka.filter.Languages.in_('EN')

# %%
pool.quality_control.training_requirement = toloka.quality_control.QualityControl.TrainingRequirement(
    training_pool_id=training_pool.id, 
    training_passing_skill_value=30,
) 

pool.quality_control.add_action(
    collector=toloka.collectors.MajorityVote(
        answer_threshold=4,
        history_size=5,
    ),
    conditions=[
        toloka.conditions.TotalAnswersCount >= 5,
        toloka.conditions.IncorrectAnswersRate > 30,
    ],
    action=toloka.actions.RestrictionV2(
        scope='PROJECT',
        duration=1,
        duration_unit='DAYS',
        private_comment='Wrong on over 30% cases',
    ),    
)

pool.quality_control.add_action(
    collector=toloka.collectors.AssignmentSubmitTime(history_size=5, fast_submit_threshold_seconds=15),
    conditions=[
        toloka.conditions.TotalSubmittedCount >= 5,
        toloka.conditions.FastSubmittedCount >= 3],
    action=toloka.actions.RestrictionV2(
        scope='PROJECT',
        duration=1,
        duration_unit='DAYS',
        private_comment='Answering too fast',
    ),    
)

pool.quality_control.add_action(
    collector=toloka.collectors.SkippedInRowAssignments(),
    conditions=[toloka.conditions.SkippedInRowCount >= 3],
    action=toloka.actions.RestrictionV2(
        scope=toloka.user_restriction.UserRestriction.PROJECT,
        duration=1,
        duration_unit='DAYS',
        private_comment='Lazy performer',
    )
)

# %%
pool = toloka_client.create_pool(pool)
# Out:
# [INFO] toloka.client: A new pool with ID "28225839" has been created. Link to open in web interface: https://toloka.yandex.com/requester/project/60772/pool/28225839

# %% [markdown]
# ## Create tasks from dataset

# %%
tasks = [
    toloka.Task(input_values={'image': url}, pool_id=pool.id)
    for url in df.img_url
]
toloka_client.create_tasks(tasks, allow_defaults=True)
# Out:
# TaskBatchCreateResult(_unexpected={}, items={'0': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/ship/n03545470_11883.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44d7', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 108000), baseline_solutions=None), '1': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02111889_9460.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44d9', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 141000), baseline_solutions=None), '2': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01645776_9028.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44db', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 195000), baseline_solutions=None), '3': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01639765_21028.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44dd', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 258000), baseline_solutions=None), '4': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/cifar10-train-45915.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44df', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 321000), baseline_solutions=None), '5': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n04490091_1445.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44e1', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 358000), baseline_solutions=None), '6': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/cifar10-test-4383.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44e3', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, traits_any_of=None, traits_none_of_any=None, origin_task_id=None, created=datetime.datetime(2021, 9, 28, 8, 39, 46, 388000), baseline_solutions=None), '7': Task(_unexpected={}, input_values={'image': 'https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_3343.png'}, known_solutions=None, message_on_unknown_solution=None, id='0001aeb12f--6152d4d250f7701c0a4f44e5', infinite_overlap=False, overlap=5, pool_id='28225839', remaining_overlap=5, reserved_for=[], unavailable_for=[], traits_all_of=None, t ...

# %% [markdown]
# # Start annotation

# %%
training_pool = toloka_client.open_pool(training_pool.id)
pool = toloka_client.open_pool(pool.id)

# %%
pool_id = pool.id

def wait_pool_for_close(pool_id, minutes_to_wait=0.5):
    sleep_time = 60 * minutes_to_wait
    pool = toloka_client.get_pool(pool_id)
    while not pool.is_closed():
        op = toloka_client.get_analytics([toloka.analytics_request.CompletionPercentagePoolAnalytics(subject_id=pool.id)])
        op = toloka_client.wait_operation(op)
        percentage = op.details['value'][0]['result']['value']
        print(
            f'   {datetime.datetime.now().strftime("%H:%M:%S")}\t'
            f'Pool {pool.id} - {percentage}%'
        )
        time.sleep(sleep_time)
        pool = toloka_client.get_pool(pool.id)
    print('Pool was closed.')

wait_pool_for_close(pool_id)
# Out:
#    11:40:42	Pool 28225839 - 0%
#    11:41:14	Pool 28225839 - 0%
#    11:41:51	Pool 28225839 - 0%
#    11:42:23	Pool 28225839 - 0%
#    11:42:56	Pool 28225839 - 1%
#    11:43:28	Pool 28225839 - 4%
#    11:44:00	Pool 28225839 - 7%
#    11:44:33	Pool 28225839 - 13%
#    11:45:06	Pool 28225839 - 20%
#    11:45:39	Pool 28225839 - 28%
#    11:46:11	Pool 28225839 - 37%
#    11:46:43	Pool 28225839 - 47%
#    11:47:15	Pool 28225839 - 59%
#    11:47:49	Pool 28225839 - 69%
#    11:48:21	Pool 28225839 - 82%
#    11:48:53	Pool 28225839 - 93%
#    11:49:25	Pool 28225839 - 96%
#    11:49:58	Pool 28225839 - 97%
#    11:50:30	Pool 28225839 - 98%
#    11:51:02	Pool 28225839 - 98%
#    11:51:35	Pool 28225839 - 98%
#    11:52:07	Pool 28225839 - 98%
#    11:52:38	Pool 28225839 - 99%
#    11:53:12	Pool 28225839 - 99%
#    11:53:44	Pool 28225839 - 99%
#    11:54:19	Pool 28225839 - 99%
#    11:54:51	Pool 28225839 - 99%
#    11:55:24	Pool 28225839 - 100%
#    11:55:56	Pool 28225839 - 100%
#    11:56:29	Pool 28225839 - 100%
#    11:57:02	Pool 28225839 - 100%
# Pool was closed.

# %%
training_pool = toloka_client.close_pool(training_pool.id)

# %% [markdown]
# # Extract results

# %%
answers_df = toloka_client.get_assignments_df(pool_id)
answers_df = answers_df.rename(columns={
    'INPUT:image': 'task',
    'OUTPUT:result': 'label',
    'ASSIGNMENT:worker_id': 'worker',
})
# Out:
# [WARNING] toloka.client: Experimental method

# %% [markdown]
# # Aggregate results

# %%
aggregated_answers = DawidSkene(n_iter=100).fit_predict(answers_df)

# %%
aggregated_answers = aggregated_answers.reset_index()
aggregated_answers.columns = ['img_url', 'pred_label']
aggregated_answers = aggregated_answers.merge(df, on='img_url')
aggregated_answers.head()
# Out:
#                                              img_url pred_label  \
# 0  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...   airplane
# 1  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...       deer
# 2  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...       deer
# 3  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...        cat
# 4  https://tlk.s3.yandex.net/ext_dataset/CINIC-10...       deer
#
#                            img_path     label
# 0  test/airplane/n02686121_2744.png  airplane
# 1   test/deer/cifar10-test-1720.png      deer
# 2      test/deer/n02419796_6293.png      deer
# 3       test/cat/n02125081_7666.png       cat
# 4   test/deer/cifar10-test-4957.png      deer

# %% [markdown]
# # View results

# %%
sample = aggregated_answers.sample(10)
captions = [f'True: {row.label}\nPred: {row.pred_label}' for row in sample.itertuples()]

ipyplot.plot_images(
    images=sample.img_url.values,
    labels=captions,
    max_images=10,
    img_width=100,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jPEv44GGfguLoDnA73U2vc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jPEv44GGfguLoDnA73U2vc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jPEv44GGfguLoDnA73U2vc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jPEv44GGfguLoDnA73U2vc:checked ~ #ipyplot-html-viewer-textarea-jPEv44GGfguLoDnA73U2vc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jPEv44GGfguLoDnA73U2vc:checked + #ipyplot-html-viewer-label-jPEv44GGfguLoDnA73U2vc:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jPEv44GGfguLoDnA73U2vc">
#         <label id="ipyplot-html-viewer-label-jPEv44GGfguLoDnA73U2vc" for="ipyplot-html-viewer-toggle-jPEv44GGfguLoDnA73U2vc">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jPEv44GGfguLoDnA73U2vc" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-cYHWXDZNUCyVYK6WiZ2SKg {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-cYHWXDZNUCyVYK6WiZ2SKg">
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-9bXGXq3E2QEDvV9HtJcTWD" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: truck
# Pred: truck</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/cifar10-test-7955.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/cifar10-test-7955.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-9bXGXq3E2QEDvV9HtJcTWD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-CTXmVYUTE8pqrzfuMfRkwF" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: frog
# Pred: frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01651059_5403.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01651059_5403.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-CTXmVYUTE8pqrzfuMfRkwF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-bhk7kcTpGZZdJkHFofJTbo" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: bird
# Pred: bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n01580870_1174.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n01580870_1174.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-bhk7kcTpGZZdJkHFofJTbo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-VShwSh4HKhLBXiHH9N4L74" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: deer
# Pred: deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_735.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_735.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-VShwSh4HKhLBXiHH9N4L74">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-FP3mpBEPYL3rAcLZgbFadd" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: truck
# Pred: automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n03930630_12390.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n03930630_12390.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-FP3mpBEPYL3rAcLZgbFadd">
#                 <span class="ipyplot-img-expand"/>
#         <style>
#         #ipyplot-imgs-container-div-cYHWXDZNUCyVYK6WiZ2SKg {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-cYHWXDZNUCyVYK6WiZ2SKg">
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-9bXGXq3E2QEDvV9HtJcTWD" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: truck
# Pred: truck</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/cifar10-test-7955.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/cifar10-test-7955.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-9bXGXq3E2QEDvV9HtJcTWD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-CTXmVYUTE8pqrzfuMfRkwF" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: frog
# Pred: frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01651059_5403.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/frog/n01651059_5403.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-CTXmVYUTE8pqrzfuMfRkwF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-bhk7kcTpGZZdJkHFofJTbo" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: bird
# Pred: bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n01580870_1174.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/bird/n01580870_1174.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-bhk7kcTpGZZdJkHFofJTbo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-VShwSh4HKhLBXiHH9N4L74" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: deer
# Pred: deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_735.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_735.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-VShwSh4HKhLBXiHH9N4L74">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-FP3mpBEPYL3rAcLZgbFadd" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: truck
# Pred: automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n03930630_12390.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n03930630_12390.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-FP3mpBEPYL3rAcLZgbFadd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-WEkjVWqBiS6YaxeKXfnXLU" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: truck
# Pred: truck</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n03173929_11315.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/truck/n03173929_11315.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-WEkjVWqBiS6YaxeKXfnXLU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-cYHWXDZNUCyVYK6WiZ2SKg">
#         <div id="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg-m95aLya6ML33kinPnSqpWf" class="ipyplot-content-div-cYHWXDZNUCyVYK6WiZ2SKg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: dog
# Pred: cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02110341_772.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02110341_772.png"/>
#             <a href="#!">
#                 <span class="ipyp

# %% [markdown]
# # View mistakes

# %%
wrong_answers = aggregated_answers[aggregated_answers.pred_label != aggregated_answers.label]
sample = wrong_answers.sample(12)
captions = [f'True: {row.label}\nPred: {row.pred_label}' for row in sample.itertuples()]

ipyplot.plot_images(
    images=sample.img_url.values,
    labels=captions,
    max_images=10,
    img_width=100,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-2MGDQcbJXKKKfoaTdPcwoQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-2MGDQcbJXKKKfoaTdPcwoQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-2MGDQcbJXKKKfoaTdPcwoQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-2MGDQcbJXKKKfoaTdPcwoQ:checked ~ #ipyplot-html-viewer-textarea-2MGDQcbJXKKKfoaTdPcwoQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-2MGDQcbJXKKKfoaTdPcwoQ:checked + #ipyplot-html-viewer-label-2MGDQcbJXKKKfoaTdPcwoQ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-2MGDQcbJXKKKfoaTdPcwoQ">
#         <label id="ipyplot-html-viewer-label-2MGDQcbJXKKKfoaTdPcwoQ" for="ipyplot-html-viewer-toggle-2MGDQcbJXKKKfoaTdPcwoQ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-2MGDQcbJXKKKfoaTdPcwoQ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ni4uQL7tJ43nCtFT8YJfou {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ni4uQL7tJ43nCtFT8YJfou">
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-KPeCGETaxFuGDWqsySVgRF" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: cat
# Pred: dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02129991_4072.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02129991_4072.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-KPeCGETaxFuGDWqsySVgRF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-DQUfKnxwKNk7xM89CcTWd6" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: deer
# Pred: frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_10947.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_10947.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-DQUfKnxwKNk7xM89CcTWd6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-SmEgtb5HH2MuvcQhR6A2k3" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: airplane
# Pred: bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/n04012084_1706.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/n04012084_1706.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-SmEgtb5HH2MuvcQhR6A2k3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-8Vhuy96J5PkjGKK75mjtsz" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: dog
# Pred: horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02087046_6326.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02087046_6326.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-8Vhuy96J5PkjGKK75mjtsz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-kKncgvo6UeHdstCR8W9SYi" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: dog
# Pred: cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02119022_406.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02119022_406.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-kKncgvo6UeHdstCR8W9SYi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </
#         <style>
#         #ipyplot-imgs-container-div-ni4uQL7tJ43nCtFT8YJfou {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ni4uQL7tJ43nCtFT8YJfou">
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-KPeCGETaxFuGDWqsySVgRF" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: cat
# Pred: dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02129991_4072.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02129991_4072.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-KPeCGETaxFuGDWqsySVgRF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-DQUfKnxwKNk7xM89CcTWd6" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: deer
# Pred: frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_10947.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/deer/n02433546_10947.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-DQUfKnxwKNk7xM89CcTWd6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-SmEgtb5HH2MuvcQhR6A2k3" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: airplane
# Pred: bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/n04012084_1706.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/airplane/n04012084_1706.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-SmEgtb5HH2MuvcQhR6A2k3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-8Vhuy96J5PkjGKK75mjtsz" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: dog
# Pred: horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02087046_6326.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02087046_6326.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-8Vhuy96J5PkjGKK75mjtsz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-kKncgvo6UeHdstCR8W9SYi" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: dog
# Pred: cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02119022_406.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/dog/n02119022_406.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-kKncgvo6UeHdstCR8W9SYi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-iQYvuwHH3DrWFTZuqiAff5" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: automobile
# Pred: truck</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03670208_1021.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/automobile/n03670208_1021.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-iQYvuwHH3DrWFTZuqiAff5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ni4uQL7tJ43nCtFT8YJfou">
#         <div id="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou-akNvJMntyR2M2HatKeQVZc" class="ipyplot-content-div-ni4uQL7tJ43nCtFT8YJfou">
#             <h4 style="font-size: 12px; word-wrap: break-word;">True: cat
# Pred: horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02130308_10004.png</h4><img src="https://tlk.s3.yandex.net/ext_dataset/CINIC-10/test/cat/n02130308_10004.png"/>
#             <a href="#!">
#                 <span class="ip

# %% [markdown]
# # Obtain accuracy

# %%
accuracy = balanced_accuracy_score(aggregated_answers.label, aggregated_answers.pred_label)
print(f'Accuracy: {accuracy:.2f}')
print(f'Error: {1-accuracy:.2f}')
# Out:
# Accuracy: 0.88
# Error: 0.12
